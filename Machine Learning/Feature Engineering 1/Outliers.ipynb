# %% [markdown]
# ### 5 Number Summary And Box Plot

# %% [markdown]
# ###### Minimum, Q1, Median, Q3, Maximum

# %%
import numpy as np

# %%
list_marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74]
minimum, Q1,median, Q3, maximum = np.quantile(list_marks, [0,0.25, 0.50, 0.75, 1.0])

# %%
minimum, maximum, Q1, Q3, median
# Out:
# (32.0, 99.0, 54.0, 89.0, 67.0)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1 - (1.5 * IQR)
higher_fence = Q3 + (1.5 * IQR)

# %%
lower_fence, higher_fence
# Out:
# (1.5, 141.5)

# %%
import seaborn as sns

# %%
sns.boxplot(list_marks)
# Out:
# <AxesSubplot: >

# %%
outlier_list_marks = [-20, 45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74,150,145,160]

# %%
sns.boxplot(outlier_list_marks)
# Out:
# <AxesSubplot: >
